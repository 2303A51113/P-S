# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51113/P-S/blob/main/Copy_of_LAB_5_P%26S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
N=500
children_counts=np.random.choice([0,1,2,3,4],size=N,p=[0.1,0.2,0.3,0.4,0.0])

# %%
unique, counts = np.unique(children_counts, return_counts=True)
pmf = counts / N #=probaility of each value

# %%
cdf=np.cumsum(pmf)

# %%
plt.figure(figsize=(10,5))
# The 'edgecolor' parameter is used to set the color of the bar edges.
sns.barplot(x=unique, y=pmf, color="Skyblue", edgecolor="black")
plt.xlabel("Number of children per family")
plt.ylabel("Probability(PMF)")
plt.title("Probability Mass Function(PMF) of family sizes")
plt.xticks(unique)
plt.show()
